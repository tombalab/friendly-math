# %% [markdown]
# Import profili i funkcję prompt builder

# %%
from app.generators.profiles.dyskalkulia import DyskalkuliaProfile
from app.generators.profiles.adhd import ADHDProfile
from app.backend.prompts.system_with_profile import build_system_prompt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from app.generators.profiles.dyskalkulia import DyskalkuliaProfile
#       2 from app.generators.profiles.adhd import ADHDProfile
#       3 from app.backend.prompts.system_with_profile import build_system_prompt
#
# ModuleNotFoundError: No module named 'app'

# %% [markdown]
# Przygotuj bazowy prompt i problem

# %%
base_prompt = """
Jesteś Friendly Math – cierpliwym nauczycielem matematyki.
Twoim celem jest tłumaczyć matematykę w sposób zrozumiały,
bez oceniania i presji.
"""

problem = "Oblicz 3 × (4 + 2)"

# %% [markdown]
# Zbuduj prompty dla obu profili

# %%
# Profil Dyskalkulia
dys_prompt = build_system_prompt(base_prompt, DyskalkuliaProfile())
# Profil ADHD
adhd_prompt = build_system_prompt(base_prompt, ADHDProfile())

# %% [markdown]
# Symulacja odpowiedzi AI

# %%
print("=== Dyskalkulia Prompt ===")
print(dys_prompt)
print("\n=== ADHD Prompt ===")
print(adhd_prompt)
